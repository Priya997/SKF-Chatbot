# %%
import json
import csv
with open("data.json",encoding='utf-8') as read_file:
        data = json.load(read_file)

# %%
a=data['items']
title=[]
for d in a:
	title.append((d['title']))
	
ques=[]
sol=[]
code=[]

# %%
print(title)
# Out:
# ['Filename injection Path traversel', 'xss injection', 'Command injection', 'Cross site request forgery', 'XXE injections', 'X Path injections', 'XML injection', 'XSLT injections', 'External DTD parsing', 'LDAP injection', 'SSI injections', 'File upload injections', 'Version management', 'Verbose error messaging', 'Debug enabeling', 'Robots.txt', 'Accessible non parsed dynamic scripts', 'Include anti', 'Include anti clickjacking headers', 'Include X XSS', 'Include X Content Type Options header', 'Include Strict Transport Security header', 'sensitive information stored in cookies', 'Client side state management', 'Too verbose authentication', 'Brute force password guessing', 'Denial of service by locking out accounts', 'Predictable password and or token generation', 'Unauthorized credential changes', 'Double decoding of headers parameters', 'Resource identifier injection', 'Dynamic scripting injection', 'Regular expression injection', 'Automated spamming via feedback scripts', 'Session cookies without the Secure flag', 'Session cookies without the HttpOnly flag', 'External session hijacking', 'Insecure transmission of session cookies', 'Unproven cryptographic algorithms', 'Client side authentication', 'Identifier based authorization', 'Principle of complete mediation', 'Prepared statements and query parameterization', 'Are all passwords hashed, salted and stretched', 'Sensitive information transmitted by unencrypted methods', 'Session information is not stored server side', 'The crossdomain xml should only contains trusted domains', 'Session ids should be generated with sufficient entropy', 'User generated session ids should be rejected by the server', 'The logout functionality should revoke the complete session', 'The login functionality should always generate a new session id', 'Does The application enforce the use of secure passwords', 'Session IDs do not timeout (idl)', 'Directory listing', 'Unnecessary features enabled or installed', 'Avoid the use of default and predictable acounts.', 'Security settings in your development frameworks', 'Insecure datastorage', 'Authentication based on the knowledge of a secret URL', 'Open forward and Open redirects', 'Incorrect or missing charset', 'Extraneous files in document root', 'Username enumeration', 'HTTP header injection', 'GET POST requests', 'Insecure internal communication', 'Sensitive information stored alongside the source code', 'The possible risks to the application must be documented', 'Possible attackers of the application must be documented', 'Audit logs', 'User credentials in audit logs', 'Intrusion detecting and reporting', 'Authentication at a central location', 'IP adresses in internal HTTP headers', 'Authentication enforced by the web sever', 'The audit log must include a priority system', 'Servers must not be trusted without explicit authentication', 'Ensure overall security', 'Re authentication', 'No shared knowledge for secret questions', 'Disallow the use of old passwords', 'Absolute session time out', 'Logout structuring', 'Verify that the session id is never disclosed', 'Session Domain cookies', 'Access control failure', 'Input rejection', 'Input validation', 'Single input validation controls', 'Logging validation failures', 'Logging implemented on the serverside', 'Logging guidelines', 'Log viewing software code injection', 'CA certificates', 'All connections should be TLS', 'Log TLS connection failures', 'Content type headers', 'Malicious intent', 'Sandboxing', 'Repudiation attack', 'Server side validation', 'Privilege escalation', 'Enforce sequential step order', 'step up or adaptive authentication', 'Cross origin resource sharing', 'Prevent password pre filling', 'All authentication controls must fail securely', 'Forget password functions', 'Aggregate access control protection', 'Canonicalized user input', 'Approved random number generator', 'Validated cryptographic modules', 'Policy for managing cryptographic keys', 'HTTPS and weakly or unencrypted links ...

# %%
for t in title:
	ques.append("What is "+ t + " ?")
	ques.append("What does "+ t + " mean ?")
	ques.append("Tell me something about "+ t + " ?")
	ques.append(t)
	ques.append("Explain " + t +" ?")
	ques.append("Elaborate " + t +" ?")
	ques.append("Can you tell me about " + t + " ?")
	ques.append("What do you know about " + t + " ?")
	ques.append("What can you tell me about " + t + " ?")
	ques.append("I want to know about XSS " + t )
	ques.append("Do you have information about " + t + " ?")

# %%
print(ques)
# Out:
# ['What is Filename injection Path traversel ?', 'What does Filename injection Path traversel mean ?', 'Tell me something about Filename injection Path traversel ?', 'Filename injection Path traversel', 'Explain Filename injection Path traversel ?', 'Elaborate Filename injection Path traversel ?', 'Can you tell me about Filename injection Path traversel ?', 'What do you know about Filename injection Path traversel ?', 'What can you tell me about Filename injection Path traversel ?', 'I want to know about XSS Filename injection Path traversel', 'Do you have information about Filename injection Path traversel ?', 'What is xss injection ?', 'What does xss injection mean ?', 'Tell me something about xss injection ?', 'xss injection', 'Explain xss injection ?', 'Elaborate xss injection ?', 'Can you tell me about xss injection ?', 'What do you know about xss injection ?', 'What can you tell me about xss injection ?', 'I want to know about XSS xss injection', 'Do you have information about xss injection ?', 'What is Command injection ?', 'What does Command injection mean ?', 'Tell me something about Command injection ?', 'Command injection', 'Explain Command injection ?', 'Elaborate Command injection ?', 'Can you tell me about Command injection ?', 'What do you know about Command injection ?', 'What can you tell me about Command injection ?', 'I want to know about XSS Command injection', 'Do you have information about Command injection ?', 'What is Cross site request forgery ?', 'What does Cross site request forgery mean ?', 'Tell me something about Cross site request forgery ?', 'Cross site request forgery', 'Explain Cross site request forgery ?', 'Elaborate Cross site request forgery ?', 'Can you tell me about Cross site request forgery ?', 'What do you know about Cross site request forgery ?', 'What can you tell me about Cross site request forgery ?', 'I want to know about XSS Cross site request forgery', 'Do you have information about Cross site request forgery ?', 'What is XXE injections ?', 'What does XXE injections mean ?', 'Tell me something about XXE injections ?', 'XXE injections', 'Explain XXE injections ?', 'Elaborate XXE injections ?', 'Can you tell me about XXE injections ?', 'What do you know about XXE injections ?', 'What can you tell me about XXE injections ?', 'I want to know about XSS XXE injections', 'Do you have information about XXE injections ?', 'What is X Path injections ?', 'What does X Path injections mean ?', 'Tell me something about X Path injections ?', 'X Path injections', 'Explain X Path injections ?', 'Elaborate X Path injections ?', 'Can you tell me about X Path injections ?', 'What do you know about X Path injections ?', 'What can you tell me about X Path injections ?', 'I want to know about XSS X Path injections', 'Do you have information about X Path injections ?', 'What is XML injection ?', 'What does XML injection mean ?', 'Tell me something about XML injection ?', 'XML injection', 'Explain XML injection ?', 'Elaborate XML injection ?', 'Can you tell me about XML injection ?', 'What do you know about XML injection ?', 'What can you tell me about XML injection ?', 'I want to know about XSS XML injection', 'Do you have information about XML injection ?', 'What is XSLT injections ?', 'What does XSLT injections mean ?', 'Tell me something about XSLT injections ?', 'XSLT injections', 'Explain XSLT injections ?', 'Elaborate XSLT injections ?', 'Can you tell me about XSLT injections ?', 'What do you know about XSLT injections ?', 'What can you tell me about XSLT injections ?', 'I want to know about XSS XSLT injections', 'Do you have information about XSLT injections ?', 'What is External DTD parsing ?', 'What does External DTD parsing mean ?', 'Tell me something about External DTD parsing ?', 'External DTD parsing', 'Explain External DTD parsing ?', 'Elaborate External DTD parsing ?', 'Can you tell me about External DTD parsing ?', 'What do you know about External DTD parsing ?', 'What can you tell me a ...

# %%
for t in title:
        sol.append("How to solve "+ t + " ?")
        sol.append("How to resolve "+ t + " ?")
        sol.append("How to mitigate "+ t + " ?")
        sol.append("Solution for "+ t)
        sol.append("Provide me some Solution for "+ t)
        sol.append("mitigation for "+ t)
        sol.append("How to stop "+ t + " ?")
        sol.append("How to defend "+ t + " ?")
        sol.append("How to get secured against "+ t + " ?")
        sol.append("Solution, "+t)

# %%
print(sol)
# Out:
# ['How to solve Filename injection Path traversel ?', 'How to resolve Filename injection Path traversel ?', 'How to mitigate Filename injection Path traversel ?', 'Solution for Filename injection Path traversel', 'Provide me some Solution for Filename injection Path traversel', 'mitigation for Filename injection Path traversel', 'How to stop Filename injection Path traversel ?', 'How to defend Filename injection Path traversel ?', 'How to get secured against Filename injection Path traversel ?', 'Solution, Filename injection Path traversel', 'How to solve xss injection ?', 'How to resolve xss injection ?', 'How to mitigate xss injection ?', 'Solution for xss injection', 'Provide me some Solution for xss injection', 'mitigation for xss injection', 'How to stop xss injection ?', 'How to defend xss injection ?', 'How to get secured against xss injection ?', 'Solution, xss injection', 'How to solve Command injection ?', 'How to resolve Command injection ?', 'How to mitigate Command injection ?', 'Solution for Command injection', 'Provide me some Solution for Command injection', 'mitigation for Command injection', 'How to stop Command injection ?', 'How to defend Command injection ?', 'How to get secured against Command injection ?', 'Solution, Command injection', 'How to solve Cross site request forgery ?', 'How to resolve Cross site request forgery ?', 'How to mitigate Cross site request forgery ?', 'Solution for Cross site request forgery', 'Provide me some Solution for Cross site request forgery', 'mitigation for Cross site request forgery', 'How to stop Cross site request forgery ?', 'How to defend Cross site request forgery ?', 'How to get secured against Cross site request forgery ?', 'Solution, Cross site request forgery', 'How to solve XXE injections ?', 'How to resolve XXE injections ?', 'How to mitigate XXE injections ?', 'Solution for XXE injections', 'Provide me some Solution for XXE injections', 'mitigation for XXE injections', 'How to stop XXE injections ?', 'How to defend XXE injections ?', 'How to get secured against XXE injections ?', 'Solution, XXE injections', 'How to solve X Path injections ?', 'How to resolve X Path injections ?', 'How to mitigate X Path injections ?', 'Solution for X Path injections', 'Provide me some Solution for X Path injections', 'mitigation for X Path injections', 'How to stop X Path injections ?', 'How to defend X Path injections ?', 'How to get secured against X Path injections ?', 'Solution, X Path injections', 'How to solve XML injection ?', 'How to resolve XML injection ?', 'How to mitigate XML injection ?', 'Solution for XML injection', 'Provide me some Solution for XML injection', 'mitigation for XML injection', 'How to stop XML injection ?', 'How to defend XML injection ?', 'How to get secured against XML injection ?', 'Solution, XML injection', 'How to solve XSLT injections ?', 'How to resolve XSLT injections ?', 'How to mitigate XSLT injections ?', 'Solution for XSLT injections', 'Provide me some Solution for XSLT injections', 'mitigation for XSLT injections', 'How to stop XSLT injections ?', 'How to defend XSLT injections ?', 'How to get secured against XSLT injections ?', 'Solution, XSLT injections', 'How to solve External DTD parsing ?', 'How to resolve External DTD parsing ?', 'How to mitigate External DTD parsing ?', 'Solution for External DTD parsing', 'Provide me some Solution for External DTD parsing', 'mitigation for External DTD parsing', 'How to stop External DTD parsing ?', 'How to defend External DTD parsing ?', 'How to get secured against External DTD parsing ?', 'Solution, External DTD parsing', 'How to solve LDAP injection ?', 'How to resolve LDAP injection ?', 'How to mitigate LDAP injection ?', 'Solution for LDAP injection', 'Provide me some Solution for LDAP injection', 'mitigation for LDAP injection', 'How to stop LDAP injection ?', 'How to defend LDAP injection ?', 'How to get secured against LDAP injection ?', 'Solution, LDAP injection', 'How to solve SSI i ...

# %%
for t in title:
        code.append("Give me some sample code of "+ t )
        code.append("Code example of "+ t + " ?")
        code.append("Code of "+ t )

# %%
print(code)
# Out:
# ['Give me some sample code of Filename injection Path traversel', 'Code example of Filename injection Path traversel ?', 'Code of Filename injection Path traversel', 'Give me some sample code of xss injection', 'Code example of xss injection ?', 'Code of xss injection', 'Give me some sample code of Command injection', 'Code example of Command injection ?', 'Code of Command injection', 'Give me some sample code of Cross site request forgery', 'Code example of Cross site request forgery ?', 'Code of Cross site request forgery', 'Give me some sample code of XXE injections', 'Code example of XXE injections ?', 'Code of XXE injections', 'Give me some sample code of X Path injections', 'Code example of X Path injections ?', 'Code of X Path injections', 'Give me some sample code of XML injection', 'Code example of XML injection ?', 'Code of XML injection', 'Give me some sample code of XSLT injections', 'Code example of XSLT injections ?', 'Code of XSLT injections', 'Give me some sample code of External DTD parsing', 'Code example of External DTD parsing ?', 'Code of External DTD parsing', 'Give me some sample code of LDAP injection', 'Code example of LDAP injection ?', 'Code of LDAP injection', 'Give me some sample code of SSI injections', 'Code example of SSI injections ?', 'Code of SSI injections', 'Give me some sample code of File upload injections', 'Code example of File upload injections ?', 'Code of File upload injections', 'Give me some sample code of Version management', 'Code example of Version management ?', 'Code of Version management', 'Give me some sample code of Verbose error messaging', 'Code example of Verbose error messaging ?', 'Code of Verbose error messaging', 'Give me some sample code of Debug enabeling', 'Code example of Debug enabeling ?', 'Code of Debug enabeling', 'Give me some sample code of Robots.txt', 'Code example of Robots.txt ?', 'Code of Robots.txt', 'Give me some sample code of Accessible non parsed dynamic scripts', 'Code example of Accessible non parsed dynamic scripts ?', 'Code of Accessible non parsed dynamic scripts', 'Give me some sample code of Include anti', 'Code example of Include anti ?', 'Code of Include anti', 'Give me some sample code of Include anti clickjacking headers', 'Code example of Include anti clickjacking headers ?', 'Code of Include anti clickjacking headers', 'Give me some sample code of Include X XSS', 'Code example of Include X XSS ?', 'Code of Include X XSS', 'Give me some sample code of Include X Content Type Options header', 'Code example of Include X Content Type Options header ?', 'Code of Include X Content Type Options header', 'Give me some sample code of Include Strict Transport Security header', 'Code example of Include Strict Transport Security header ?', 'Code of Include Strict Transport Security header', 'Give me some sample code of sensitive information stored in cookies', 'Code example of sensitive information stored in cookies ?', 'Code of sensitive information stored in cookies', 'Give me some sample code of Client side state management', 'Code example of Client side state management ?', 'Code of Client side state management', 'Give me some sample code of Too verbose authentication', 'Code example of Too verbose authentication ?', 'Code of Too verbose authentication', 'Give me some sample code of Brute force password guessing', 'Code example of Brute force password guessing ?', 'Code of Brute force password guessing', 'Give me some sample code of Denial of service by locking out accounts', 'Code example of Denial of service by locking out accounts ?', 'Code of Denial of service by locking out accounts', 'Give me some sample code of Predictable password and or token generation', 'Code example of Predictable password and or token generation ?', 'Code of Predictable password and or token generation', 'Give me some sample code of Unauthorized credential changes', 'Code example of Unauthorized credential changes ?', 'Code of Unauthorized credential changes', 'Gi ...

# %%
file=open("intent_data.csv","x")

# %%
file.write('class, question\n')
for x in ques:
		x=x.replace(",","")
		file.write('Description, '+x+"\n")

# %%
for y in sol:
		y=y.replace(",","")
		file.write('Solution, '+y+"\n")

# %%
for z in code:
		z=z.replace(",","")
		file.write('Code, '+z+"\n")

# %%
file.close()

# %%
with open('intent_data.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        print(row)
# Out:
# ['class', ' question']
# ['Description', ' What is Filename injection Path traversel ?']
# ['Description', ' What does Filename injection Path traversel mean ?']
# ['Description', ' Tell me something about Filename injection Path traversel ?']
# ['Description', ' Filename injection Path traversel']
# ['Description', ' Explain Filename injection Path traversel ?']
# ['Description', ' Elaborate Filename injection Path traversel ?']
# ['Description', ' Can you tell me about Filename injection Path traversel ?']
# ['Description', ' What do you know about Filename injection Path traversel ?']
# ['Description', ' What can you tell me about Filename injection Path traversel ?']
# ['Description', ' I want to know about XSS Filename injection Path traversel']
# ['Description', ' Do you have information about Filename injection Path traversel ?']
# ['Description', ' What is xss injection ?']
# ['Description', ' What does xss injection mean ?']
# ['Description', ' Tell me something about xss injection ?']
# ['Description', ' xss injection']
# ['Description', ' Explain xss injection ?']
# ['Description', ' Elaborate xss injection ?']
# ['Description', ' Can you tell me about xss injection ?']
# ['Description', ' What do you know about xss injection ?']
# ['Description', ' What can you tell me about xss injection ?']
# ['Description', ' I want to know about XSS xss injection']
# ['Description', ' Do you have information about xss injection ?']
# ['Description', ' What is Command injection ?']
# ['Description', ' What does Command injection mean ?']
# ['Description', ' Tell me something about Command injection ?']
# ['Description', ' Command injection']
# ['Description', ' Explain Command injection ?']
# ['Description', ' Elaborate Command injection ?']
# ['Description', ' Can you tell me about Command injection ?']
# ['Description', ' What do you know about Command injection ?']
# ['Description', ' What can you tell me about Command injection ?']
# ['Description', ' I want to know about XSS Command injection']
# ['Description', ' Do you have information about Command injection ?']
# ['Description', ' What is Cross site request forgery ?']
# ['Description', ' What does Cross site request forgery mean ?']
# ['Description', ' Tell me something about Cross site request forgery ?']
# ['Description', ' Cross site request forgery']
# ['Description', ' Explain Cross site request forgery ?']
# ['Description', ' Elaborate Cross site request forgery ?']
# ['Description', ' Can you tell me about Cross site request forgery ?']
# ['Description', ' What do you know about Cross site request forgery ?']
# ['Description', ' What can you tell me about Cross site request forgery ?']
# ['Description', ' I want to know about XSS Cross site request forgery']
# ['Description', ' Do you have information about Cross site request forgery ?']
# ['Description', ' What is XXE injections ?']
# ['Description', ' What does XXE injections mean ?']
# ['Description', ' Tell me something about XXE injections ?']
# ['Description', ' XXE injections']
# ['Description', ' Explain XXE injections ?']
# ['Description', ' Elaborate XXE injections ?']
# ['Description', ' Can you tell me about XXE injections ?']
# ['Description', ' What do you know about XXE injections ?']
# ['Description', ' What can you tell me about XXE injections ?']
# ['Description', ' I want to know about XSS XXE injections']
# ['Description', ' Do you have information about XXE injections ?']
# ['Description', ' What is X Path injections ?']
# ['Description', ' What does X Path injections mean ?']
# ['Description', ' Tell me something about X Path injections ?']
# ['Description', ' X Path injections']
# ['Description', ' Explain X Path injections ?']
# ['Description', ' Elaborate X Path injections ?']
# ['Description', ' Can you tell me about X Path injections ?']
# ['Description', ' What do you know about X Path injections ?']
# ['Description', ' What can you tell me about X Path injections ?']
# ['Description', ' I want to know about XSS X Path injections']
# ['Description', ' Do you have information about X Path injections ?']
# ['Description', ' What is XML injection ?']
# ['Description', ' What does XML injection mean ?']
# ['Description', ' Tell me something about XML injection ?']
# ['Description', ' XML injection']
# ['Description', ' Explain XML injection ?']
# ['Description', ' Elaborate XML injection ?']
# ['Description', ' Can you tell me about XML injection ?']
# ['Description', ' What do you know about XML injection ?']
# ['Description', ' What can you tell me about XML injection ?']
# ['Description', ' I want to know about XSS XML injection']
# ['Description', ' Do you have information about XML injection ?']
# ['Description', ' What is XSLT injections ?']
# ['Description', ' What does XSLT injections mean ?']
# ['Description', ' Tell me something about XSLT injections ?']
# ['Description', ' XSLT injections']
# ['Description', ' Explain XSLT injections ?']
# ['Description', ' Elaborate XSLT injections ?']
# ['Description', ' Can you tell me about XSLT injections ?']
# ['Description', ' What do you know about XSLT injections ?']
# ['Description', ' What can you tell me about XSLT injections ?']
# ['Description', ' I want to know about XSS XSLT injections']
# ['Description', ' Do you have information about XSLT injections ?']
# ['Description', ' What is External DTD parsing ?']
# ['Description', ' What does External DTD parsing mean ?']
# ['Description', ' Tell me something about External DTD parsing ?']
# ['Description', ' External DTD parsing']
# ['Description', ' Explain External DTD parsing ?']
# ['Description', ' Elaborate External DTD parsing ?']
# ['Description', ' Can you tell me about External DTD parsing ?']
# ['Description', ' What do you know about External DTD parsing ?']
# ['Description', ' What can you tell me about External DTD parsing ?']
# ['Description', ' I want to know about XSS External DTD parsing']
# ['Description', ' Do you have information about External DTD parsing ?']
# ['Description', ' What is LDAP injection ?']
# ['Description', ' What does LDAP injection mean ?']
# ['Description', ' Tell me something about LDAP injection ?']
# ['Description', ' LDAP injection']
# ['Description', ' Explain LDAP injection ?']
# ['Description', ' Elaborate LDAP injection ?']
# ['Description', ' Can you tell me about LDAP injection ?']
# ['Description', ' What do you know about LDAP injection ?']
# ['Description', ' What can you tell me about LDAP injection ?']
# ['Description', ' I want to know about XSS LDAP injection']
# ['Description', ' Do you have information about LDAP injection ?']
# ['Description', ' What is SSI injections ?']
# ['Description', ' What does SSI injections mean ?']
# ['Description', ' Tell me something about SSI injections ?']
# ['Description', ' SSI injections']
# ['Description', ' Explain SSI injections ?']
# ['Description', ' Elaborate SSI injections ?']
# ['Description', ' Can you tell me about SSI injections ?']
# ['Description', ' What do you know about SSI injections ?']
# ['Description', ' What can you tell me about SSI injections ?']
# ['Description', ' I want to know about XSS SSI injections']
# ['Description', ' Do you have information about SSI injections ?']
# ['Description', ' What is File upload injections ?']
# ['Description', ' What does File upload injections mean ?']
# ['Description', ' Tell me something about File upload injections ?']
# ['Description', ' File upload injections']
# ['Description', ' Explain File upload injections ?']
# ['Description', ' Elaborate File upload injections ?']
# ['Description', ' Can you tell me about File upload injections ?']
# ['Description', ' What do you know about File upload injections ?']
# ['Description', ' What can you tell me about File upload injections ?']
# ['Description', ' I want to know about XSS File upload injections']
# ['Description', ' Do you have information about File upload injections ?']
# ['Description', ' What is Version management ?']
# ['Description', ' What does Version management mean ?']
# ['Description', ' Tell me something about Version management ?']
# ['Description', ' Version management']
# ['Description', ' Explain Version management ?']
# ['Description', ' Elaborate Version management ?']
# ['Description', ' Can you tell me about Version management ?']
# ['Description', ' What do you know about Version management ?']
# ['Description', ' What can you tell me about Version management ?']
# ['Description', ' I want to know about XSS Version management']
# ['Description', ' Do you have information about Version management ?']
# ['Description', ' What is Verbose error messaging ?']
# ['Description', ' What does Verbose error messaging mean ?']
# ['Description', ' Tell me something about Verbose error messaging ?']
# ['Description', ' Verbose error messaging']
# ['Description', ' Explain Verbose error messaging ?']
# ['Description', ' Elaborate Verbose error messaging ?']
# ['Description', ' Can you tell me about Verbose error messaging ?']
# ['Description', ' What do you know about Verbose error messaging ?']
# ['Description', ' What can you tell me about Verbose error messaging ?']
# ['Description', ' I want to know about XSS Verbose error messaging']
# ['Description', ' Do you have information about Verbose error messaging ?']
# ['Description', ' What is Debug enabeling ?']
# ['Description', ' What does Debug enabeling mean ?']
# ['Description', ' Tell me something about Debug enabeling ?']
# ['Description', ' Debug enabeling']
# ['Description', ' Explain Debug enabeling ?']
# ['Description', ' Elaborate Debug enabeling ?']
# ['Description', ' Can you tell me about Debug enabeling ?']
# ['Description', ' What do you know about Debug enabeling ?']
# ['Description', ' What can you tell me about Debug enabeling ?']
# ['Description', ' I want to know about XSS Debug enabeling']
# ['Description', ' Do you have information about Debug enabeling ?']
# ['Description', ' What is Robots.txt ?']
# ['Description', ' What does Robots.txt mean ?']
# ['Description', ' Tell me something about Robots.txt ?']
# ['Description', ' Robots.txt']
# ['Description', ' Explain Robots.txt ?']
# ['Description', ' Elaborate Robots.txt ?']
# ['Description', ' Can you tell me about Robots.txt ?']
# ['Description', ' What do you know about Robots.txt ?']
# ['Description', ' What can you tell me about Robots.txt ?']
# ['Description', ' I want to know about XSS Robots.txt']
# ['Description', ' Do you have information about Robots.txt ?']
# ['Description', ' What is Accessible non parsed dynamic scripts ?']
# ['Description', ' What does Accessible non parsed dynamic scripts mean ?']
# ['Description', ' Tell me something about Accessible non parsed dynamic scripts ?']
# ['Description', ' Accessible non parsed dynamic scripts']
# ['Description', ' Explain Accessible non parsed dynamic scripts ?']
# ['Description', ' Elaborate Accessible non parsed dynamic scripts ?']
# ['Description', ' Can you tell me about Accessible non parsed dynamic scripts ?']
# ['Description', ' What do you know about Accessible non parsed dynamic scripts ?']
# ['Description', ' What can you tell me about Accessible non parsed dynamic scripts ?']
# ['Description', ' I want to know about XSS Accessible non parsed dynamic scripts']
# ['Description', ' Do you have information about Accessible non parsed dynamic scripts ?']
# ['Description', ' What is Include anti ?']
# ['Description', ' What does Include anti mean ?']
# ['Description', ' Tell me something about Include anti ?']
# ['Description', ' Include anti']
# ['Description', ' Explain Include anti ?']
# ['Description', ' Elaborate Include anti ?']
# ['Description', ' Can you tell me about Include anti ?']
# ['Description', ' What do you know about Include anti ?']
# ['Description', ' What can you tell me about Include anti ?']
# ['Description', ' I want to know about XSS Include anti']
# ['Description', ' Do you have information about Include anti ?']
# ['Description', ' What is Include anti clickjacking headers ?']
# ['Description', ' What does Include anti clickjacking headers mean ?']
# ['Description', ' Tell me something about Include anti clickjacking headers ?']
# ['Description', ' Include anti clickjacking headers']
# ['Description', ' Explain Include anti clickjacking headers ?']
# ['Description', ' Elaborate Include anti clickjacking headers ?']
# ['Description', ' Can you tell me about Include anti clickjacking headers ?']
# ['Description', ' What do you know about Include anti clickjacking headers ?']
# ['Description', ' What can you tell me about Include anti clickjacking headers ?']
# ['Description', ' I want to know about XSS Include anti clickjacking headers']
# ['Description', ' Do you have information about Include anti clickjacking headers ?']
# ['Description', ' What is Include X XSS ?']
# ['Description', ' What does Include X XSS mean ?']
# ['Description', ' Tell me something about Include X XSS ?']
# ['Description', ' Include X XSS']
# ['Description', ' Explain Include X XSS ?']
# ['Description', ' Elaborate Include X XSS ?']
# ['Description', ' Can you tell me about Include X XSS ?']
# ['Description', ' What do you know about Include X XSS ?']
# ['Description', ' What can you tell me about Include X XSS ?']
# ['Description', ' I want to know about XSS Include X XSS']
# ['Description', ' Do you have information about Include X XSS ?']
# ['Description', ' What is Include X Content Type Options header ?']
# ['Description', ' What does Include X Content Type Options header mean ?']
# ['Description', ' Tell me something about Include X Content Type Options header ?']
# ['Description', ' Include X Content Type Options header']
# ['Description', ' Explain Include X Content Type Options header ?']
# ['Description', ' Elaborate Include X Content Type Options header ?']
# ['Description', ' Can you tell me about Include X Content Type Options header ?']
# ['Description', ' What do you know about Include X Content Type Options header ?']
# ['Description', ' What can you tell me about Include X Content Type Options header ?']
# ['Description', ' I want to know about XSS Include X Content Type Options header']
# ['Description', ' Do you have information about Include X Content Type Options header ?']
# ['Description', ' What is Include Strict Transport Security header ?']
# ['Description', ' What does Include Strict Transport Security header mean ?']
# ['Description', ' Tell me something about Include Strict Transport Security header ?']
# ['Description', ' Include Strict Transport Security header']
# ['Description', ' Explain Include Strict Transport Security header ?']
# ['Description', ' Elaborate Include Strict Transport Security header ?']
# ['Description', ' Can you tell me about Include Strict Transport Security header ?']
# ['Description', ' What do you know about Include Strict Transport Security header ?']
# ['Description', ' What can you tell me about Include Strict Transport Security header ?']
# ['Description', ' I want to know about XSS Include Strict Transport Security header']
# ['Description', ' Do you have information about Include Strict Transport Security header ?']
# ['Description', ' What is sensitive information stored in cookies ?']
# ['Description', ' What does sensitive information stored in cookies mean ?']
# ['Description', ' Tell me something about sensitive information stored in cookies ?']
# ['Description', ' sensitive information stored in cookies']
# ['Description', ' Explain sensitive information stored in cookies ?']
# ['Description', ' Elaborate sensitive information stored in cookies ?']
# ['Description', ' Can you tell me about sensitive information stored in cookies ?']
# ['Description', ' What do you know about sensitive information stored in cookies ?']
# ['Description', ' What can you tell me about sensitive information stored in cookies ?']
# ['Description', ' I want to know about XSS sensitive information stored in cookies']
# ['Description', ' Do you have information about sensitive information stored in cookies ?']
# ['Description', ' What is Client side state management ?']
# ['Description', ' What does Client side state management mean ?']
# ['Description', ' Tell me something about Client side state management ?']
# ['Description', ' Client side state management']
# ['Description', ' Explain Client side state management ?']
# ['Description', ' Elaborate Client side state management ?']
# ['Description', ' Can you tell me about Client side state management ?']
# ['Description', ' What do you know about Client side state management ?']
# ['Description', ' What can you tell me about Client side state management ?']
# ['Description', ' I want to know about XSS Client side state management']
# ['Description', ' Do you have information about Client side state management ?']
# ['Description', ' What is Too verbose authentication ?']
# ['Description', ' What does Too verbose authentication mean ?']
# ['Description', ' Tell me something about Too verbose authentication ?']
# ['Description', ' Too verbose authentication']
# ['Description', ' Explain Too verbose authentication ?']
# ['Description', ' Elaborate Too verbose authentication ?']
# ['Description', ' Can you tell me about Too verbose authentication ?']
# ['Description', ' What do you know about Too verbose authentication ?']
# ['Description', ' What can you tell me about Too verbose authentication ?']
# ['Description', ' I want to know about XSS Too verbose authentication']
# ['Description', ' Do you have information about Too verbose authentication ?']
# ['Description', ' What is Brute force password guessing ?']
# ['Description', ' What does Brute force password guessing mean ?']
# ['Description', ' Tell me something about Brute force password guessing ?']
# ['Description', ' Brute force password guessing']
# ['Description', ' Explain Brute force password guessing ?']
# ['Description', ' Elaborate Brute force password guessing ?']
# ['Description', ' Can you tell me about Brute force password guessing ?']
# ['Description', ' What do you know about Brute force password guessing ?']
# ['Description', ' What can you tell me about Brute force password guessing ?']
# ['Description', ' I want to know about XSS Brute force password guessing']
# ['Description', ' Do you have information about Brute force password guessing ?']
# ['Description', ' What is Denial of service by locking out accounts ?']
# ['Description', ' What does Denial of service by locking out accounts mean ?']
# ['Description', ' Tell me something about Denial of service by locking out accounts ?']
# ['Description', ' Denial of service by locking out accounts']
# ['Description', ' Explain Denial of service by locking out accounts ?']
# ['Description', ' Elaborate Denial of service by locking out accounts ?']
# ['Description', ' Can you tell me about Denial of service by locking out accounts ?']
# ['Description', ' What do you know about Denial of service by locking out accounts ?']
# ['Description', ' What can you tell me about Denial of service by locking out accounts ?']
# ['Description', ' I want to know about XSS Denial of service by locking out accounts']
# ['Description', ' Do you have information about Denial of service by locking out accounts ?']
# ['Description', ' What is Predictable password and or token generation ?']
# ['Description', ' What does Predictable password and or token generation mean ?']
# ['Description', ' Tell me something about Predictable password and or token generation ?']
# ['Description', ' Predictable password and or token generation']
# ['Description', ' Explain Predictable password and or token generation ?']
# ['Description', ' Elaborate Predictable password and or token generation ?']
# ['Description', ' Can you tell me about Predictable password and or token generation ?']
# ['Description', ' What do you know about Predictable password and or token generation ?']
# ['Description', ' What can you tell me about Predictable password and or token generation ?']
# ['Description', ' I want to know about XSS Predictable password and or token generation']
# ['Description', ' Do you have information about Predictable password and or token generation ?']
# ['Description', ' What is Unauthorized credential changes ?']
# ['Description', ' What does Unauthorized credential changes mean ?']
# ['Description', ' Tell me something about Unauthorized credential changes ?']
# ['Description', ' Unauthorized credential changes']
# ['Description', ' Explain Unauthorized credential changes ?']
# ['Description', ' Elaborate Unauthorized credential changes ?']
# ['Description', ' Can you tell me about Unauthorized credential changes ?']
# ['Description', ' What do you know about Unauthorized credential changes ?']
# ['Description', ' What can you tell me about Unauthorized credential changes ?']
# ['Description', ' I want to know about XSS Unauthorized credential changes']
# ['Description', ' Do you have information about Unauthorized credential changes ?']
# ['Description', ' What is Double decoding of headers parameters ?']
# ['Description', ' What does Double decoding of headers parameters mean ?']
# ['Description', ' Tell me something about Double decoding of headers parameters ?']
# ['Description', ' Double decoding of headers parameters']
# ['Description', ' Explain Double decoding of headers parameters ?']
# ['Description', ' Elaborate Double decoding of headers parameters ?']
# ['Description', ' Can you tell me about Double decoding of headers parameters ?']
# ['Description', ' What do you know about Double decoding of headers parameters ?']
# ['Description', ' What can you tell me about Double decoding of headers parameters ?']
# ['Description', ' I want to know about XSS Double decoding of headers parameters']
# ['Description', ' Do you have information about Double decoding of headers parameters ?']
# ['Description', ' What is Resource identifier injection ?']
# ['Description', ' What does Resource identifier injection mean ?']
# ['Description', ' Tell me something about Resource identifier injection ?']
# ['Description', ' Resource identifier injection']
# ['Description', ' Explain Resource identifier injection ?']
# ['Description', ' Elaborate Resource identifier injection ?']
# ['Description', ' Can you tell me about Resource identifier injection ?']
# ['Description', ' What do you know about Resource identifier injection ?']
# ['Description', ' What can you tell me about Resource identifier injection ?']
# ['Description', ' I want to know about XSS Resource identifier injection']
# ['Description', ' Do you have information about Resource identifier injection ?']
# ['Description', ' What is Dynamic scripting injection ?']
# ['Description', ' What does Dynamic scripting injection mean ?']
# ['Description', ' Tell me something about Dynamic scripting injection ?']
# ['Description', ' Dynamic scripting injection']
# ['Description', ' Explain Dynamic scripting injection ?']
# ['Description', ' Elaborate Dynamic scripting injection ?']
# ['Description', ' Can you tell me about Dynamic scripting injection ?']
# ['Description', ' What do you know about Dynamic scripting injection ?']
# ['Description', ' What can you tell me about Dynamic scripting injection ?']
# ['Description', ' I want to know about XSS Dynamic scripting injection']
# ['Description', ' Do you have information about Dynamic scripting injection ?']
# ['Description', ' What is Regular expression injection ?']
# ['Description', ' What does Regular expression injection mean ?']
# ['Description', ' Tell me something about Regular expression injection ?']
# ['Description', ' Regular expression injection']
# ['Description', ' Explain Regular expression injection ?']
# ['Description', ' Elaborate Regular expression injection ?']
# ['Description', ' Can you tell me about Regular expression injection ?']
# ['Description', ' What do you know about Regular expression injection ?']
# ['Description', ' What can you tell me about Regular expression injection ?']
# ['Description', ' I want to know about XSS Regular expression injection']
# ['Description', ' Do you have information about Regular expression injection ?']
# ['Description', ' What is Automated spamming via feedback scripts ?']
# ['Description', ' What does Automated spamming via feedback scripts mean ?']
# ['Description', ' Tell me something about Automated spamming via feedback scripts ?']
# ['Description', ' Automated spamming via feedback scripts']
# ['Description', ' Explain Automated spamming via feedback scripts ?']
# ['Description', ' Elaborate Automated spamming via feedback scripts ?']
# ['Description', ' Can you tell me about Automated spamming via feedback scripts ?']
# ['Description', ' What do you know about Automated spamming via feedback scripts ?']
# ['Description', ' What can you tell me about Automated spamming via feedback scripts ?']
# ['Description', ' I want to know about XSS Automated spamming via feedback scripts']
# ['Description', ' Do you have information about Automated spamming via feedback scripts ?']
# ['Description', ' What is Session cookies without the Secure flag ?']
# ['Description', ' What does Session cookies without the Secure flag mean ?']
# ['Description', ' Tell me something about Session cookies without the Secure flag ?']
# ['Description', ' Session cookies without the Secure flag']
# ['Description', ' Explain Session cookies without the Secure flag ?']
# ['Description', ' Elaborate Session cookies without the Secure flag ?']
# ['Description', ' Can you tell me about Session cookies without the Secure flag ?']
# ['Description', ' What do you know about Session cookies without the Secure flag ?']
# ['Description', ' What can you tell me about Session cookies without the Secure flag ?']
# ['Description', ' I want to know about XSS Session cookies without the Secure flag']
# ['Description', ' Do you have information about Session cookies without the Secure flag ?']
# ['Description', ' What is Session cookies without the HttpOnly flag ?']
# ['Description', ' What does Session cookies without the HttpOnly flag mean ?']
# ['Description', ' Tell me something about Session cookies without the HttpOnly flag ?']
# ['Description', ' Session cookies without the HttpOnly flag']
# ['Description', ' Explain Session cookies without the HttpOnly flag ?']
# ['Description', ' Elaborate Session cookies without the HttpOnly flag ?']
# ['Description', ' Can you tell me about Session cookies without the HttpOnly flag ?']
# ['Description', ' What do you know about Session cookies without the HttpOnly flag ?']
# ['Description', ' What can you tell me about Session cookies without the HttpOnly flag ?']
# ['Description', ' I want to know about XSS Session cookies without the HttpOnly flag']
# ['Description', ' Do you have information about Session cookies without the HttpOnly flag ?']
# ['Description', ' What is External session hijacking ?']
# ['Description', ' What does External session hijacking mean ?']
# ['Description', ' Tell me something about External session hijacking ?']
# ['Description', ' External session hijacking']
# ['Description', ' Explain External session hijacking ?']
# ['Description', ' Elaborate External session hijacking ?']
# ['Description', ' Can you tell me about External session hijacking ?']
# ['Description', ' What do you know about External session hijacking ?']
# ['Description', ' What can you tell me about External session hijacking ?']
# ['Description', ' I want to know about XSS External session hijacking']
# ['Description', ' Do you have information about External session hijacking ?']
# ['Description', ' What is Insecure transmission of session cookies ?']
# ['Description', ' What does Insecure transmission of session cookies mean ?']
# ['Description', ' Tell me something about Insecure transmission of session cookies ?']
# ['Description', ' Insecure transmission of session cookies']
# ['Description', ' Explain Insecure transmission of session cookies ?']
# ['Description', ' Elaborate Insecure transmission of session cookies ?']
# ['Description', ' Can you tell me about Insecure transmission of session cookies ?']
# ['Description', ' What do you know about Insecure transmission of session cookies ?']
# ['Description', ' What can you tell me about Insecure transmission of session cookies ?']
# ['Description', ' I want to know about XSS Insecure transmission of session cookies']
# ['Description', ' Do you have information about Insecure transmission of session cookies ?']
# ['Description', ' What is Unproven cryptographic algorithms ?']
# ['Description', ' What does Unproven cryptographic algorithms mean ?']
# ['Description', ' Tell me something about Unproven cryptographic algorithms ?']
# ['Description', ' Unproven cryptographic algorithms']
# ['Description', ' Explain Unproven cryptographic algorithms ?']
# ['Description', ' Elaborate Unproven cryptographic algorithms ?']
# ['Description', ' Can you tell me about Unproven cryptographic algorithms ?']
# ['Description', ' What do you know about Unproven cryptographic algorithms ?']
# ['Description', ' What can you tell me about Unproven cryptographic algorithms ?']
# ['Description', ' I want to know about XSS Unproven cryptographic algorithms']
# ['Description', ' Do you have information about Unproven cryptographic algorithms ?']
# ['Description', ' What is Client side authentication ?']
# ['Description', ' What does Client side authentication mean ?']
# ['Description', ' Tell me something about Client side authentication ?']
# ['Description', ' Client side authentication']
# ['Description', ' Explain Client side authentication ?']
# ['Description', ' Elaborate Client side authentication ?']
# ['Description', ' Can you tell me about Client side authentication ?']
# ['Description', ' What do you know about Client side authentication ?']
# ['Description', ' What can you tell me about Client side authentication ?']
# ['Description', ' I want to know about XSS Client side authentication']
# ['Description', ' Do you have information about Client side authentication ?']
# ['Description', ' What is Identifier based authorization ?']
# ['Description', ' What does Identifier based authorization mean ?']
# ['Description', ' Tell me something about Identifier based authorization ?']
# ['Description', ' Identifier based authorization']
# ['Description', ' Explain Identifier based authorization ?']
# ['Description', ' Elaborate Identifier based authorization ?']
# ['Description', ' Can you tell me about Identifier based authorization ?']
# ['Description', ' What do you know about Identifier based authorization ?']
# ['Description', ' What can you tell me about Identifier based authorization ?']
# ['Description', ' I want to know about XSS Identifier based authorization']
# ['Description', ' Do you have information about Identifier based authorization ?']
# ['Description', ' What is Principle of complete mediation ?']
# ['Description', ' What does Principle of complete mediation mean ?']
# ['Description', ' Tell me something about Principle of complete mediation ?']
# ['Description', ' Principle of complete mediation']
# ['Description', ' Explain Principle of complete mediation ?']
# ['Description', ' Elaborate Principle of complete mediation ?']
# ['Description', ' Can you tell me about Principle of complete mediation ?']
# ['Description', ' What do you know about Principle of complete mediation ?']
# ['Description', ' What can you tell me about Principle of complete mediation ?']
# ['Description', ' I want to know about XSS Principle of complete mediation']
# ['Description', ' Do you have information about Principle of complete mediation ?']
# ['Description', ' What is Prepared statements and query parameterization ?']
# ['Description', ' What does Prepared statements and query parameterization mean ?']
# ['Description', ' Tell me something about Prepared statements and query parameterization ?']
# ['Description', ' Prepared statements and query parameterization']
# ['Description', ' Explain Prepared statements and query parameterization ?']
# ['Description', ' Elaborate Prepared statements and query parameterization ?']
# ['Description', ' Can you tell me about Prepared statements and query parameterization ?']
# ['Description', ' What do you know about Prepared statements and query parameterization ?']
# ['Description', ' What can you tell me about Prepared statements and query parameterization ?']
# ['Description', ' I want to know about XSS Prepared statements and query parameterization']
# ['Description', ' Do you have information about Prepared statements and query parameterization ?']
# ['Description', ' What is Are all passwords hashed salted and stretched ?']
# ['Description', ' What does Are all passwords hashed salted and stretched mean ?']
# ['Description', ' Tell me something about Are all passwords hashed salted and stretched ?']
# ['Description', ' Are all passwords hashed salted and stretched']
# ['Description', ' Explain Are all passwords hashed salted and stretched ?']
# ['Description', ' Elaborate Are all passwords hashed salted and stretched ?']
# ['Description', ' Can you tell me about Are all passwords hashed salted and stretched ?']
# ['Description', ' What do you know about Are all passwords hashed salted and stretched ?']
# ['Description', ' What can you tell me about Are all passwords hashed salted and stretched ?']
# ['Description', ' I want to know about XSS Are all passwords hashed salted and stretched']
# ['Description', ' Do you have information about Are all passwords hashed salted and stretched ?']
# ['Description', ' What is Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' What does Sensitive information transmitted by unencrypted methods mean ?']
# ['Description', ' Tell me something about Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' Sensitive information transmitted by unencrypted methods']
# ['Description', ' Explain Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' Elaborate Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' Can you tell me about Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' What do you know about Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' What can you tell me about Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' I want to know about XSS Sensitive information transmitted by unencrypted methods']
# ['Description', ' Do you have information about Sensitive information transmitted by unencrypted methods ?']
# ['Description', ' What is Session information is not stored server side ?']
# ['Description', ' What does Session information is not stored server side mean ?']
# ['Description', ' Tell me something about Session information is not stored server side ?']
# ['Description', ' Session information is not stored server side']
# ['Description', ' Explain Session information is not stored server side ?']
# ['Description', ' Elaborate Session information is not stored server side ?']
# ['Description', ' Can you tell me about Session information is not stored server side ?']
# ['Description', ' What do you know about Session information is not stored server side ?']
# ['Description', ' What can you tell me about Session information is not stored server side ?']
# ['Description', ' I want to know about XSS Session information is not stored server side']
# ['Description', ' Do you have information about Session information is not stored server side ?']
# ['Description', ' What is The crossdomain xml should only contains trusted domains ?']
# ['Description', ' What does The crossdomain xml should only contains trusted domains mean ?']
# ['Description', ' Tell me something about The crossdomain xml should only contains trusted domains ?']
# ['Description', ' The crossdomain xml should only contains trusted domains']
# ['Description', ' Explain The crossdomain xml should only contains trusted domains ?']
# ['Description', ' Elaborate The crossdomain xml should only contains trusted domains ?']
# ['Description', ' Can you tell me about The crossdomain xml should only contains trusted domains ?']
# ['Description', ' What do you know about The crossdomain xml should only contains trusted domains ?']
# ['Description', ' What can you tell me about The crossdomain xml should only contains trusted domains ?']
# ['Description', ' I want to know about XSS The crossdomain xml should only contains trusted domains']
# ['Description', ' Do you have information about The crossdomain xml should only contains trusted domains ?']
# ['Description', ' What is Session ids should be generated with sufficient entropy ?']
# ['Description', ' What does Session ids should be generated with sufficient entropy mean ?']
# ['Description', ' Tell me something about Session ids should be generated with sufficient entropy ?']
# ['Description', ' Session ids should be generated with sufficient entropy']
# ['Description', ' Explain Session ids should be generated with sufficient entropy ?']
# ['Description', ' Elaborate Session ids should be generated with sufficient entropy ?']
# ['Description', ' Can you tell me about Session ids should be generated with sufficient entropy ?']
# ['Description', ' What do you know about Session ids should be generated with sufficient entropy ?']
# ['Description', ' What can you tell me about Session ids should be generated with sufficient entropy ?']
# ['Description', ' I want to know about XSS Session ids should be generated with sufficient entropy']
# ['Description', ' Do you have information about Session ids should be generated with sufficient entropy ?']
# ['Description', ' What is User generated session ids should be rejected by the server ?']
# ['Description', ' What does User generated session ids should be rejected by the server mean ?']
# ['Description', ' Tell me something about User generated session ids should be rejected by the server ?']
# ['Description', ' User generated session ids should be rejected by the server']
# ['Description', ' Explain User generated session ids should be rejected by the server ?']
# ['Description', ' Elaborate User generated session ids should be rejected by the server ?']
# ['Description', ' Can you tell me about User generated session ids should be rejected by the server ?']
# ['Description', ' What do you know about User generated session ids should be rejected by the server ?']
# ['Description', ' What can you tell me about User generated session ids should be rejected by the server ?']
# ['Description', ' I want to know about XSS User generated session ids should be rejected by the server']
# ['Description', ' Do you have information about User generated session ids should be rejected by the server ?']
# ['Description', ' What is The logout functionality should revoke the complete session ?']
# ['Description', ' What does The logout functionality should revoke the complete session mean ?']
# ['Description', ' Tell me something about The logout functionality should revoke the complete session ?']
# ['Description', ' The logout functionality should revoke the complete session']
# ['Description', ' Explain The logout functionality should revoke the complete session ?']
# ['Description', ' Elaborate The logout functionality should revoke the complete session ?']
# ['Description', ' Can you tell me about The logout functionality should revoke the complete session ?']
# ['Description', ' What do you know about The logout functionality should revoke the complete session ?']
# ['Description', ' What can you tell me about The logout functionality should revoke the complete session ?']
# ['Description', ' I want to know about XSS The logout functionality should revoke the complete session']
# ['Description', ' Do you have information about The logout functionality should revoke the complete session ?']
# ['Description', ' What is The login functionality should always generate a new session id ?']
# ['Description', ' What does The login functionality should always generate a new session id mean ?']
# ['Description', ' Tell me something about The login functionality should always generate a new session id ?']
# ['Description', ' The login functionality should always generate a new session id']
# ['Description', ' Explain The login functionality should always generate a new session id ?']
# ['Description', ' Elaborate The login functionality should always generate a new session id ?']
# ['Description', ' Can you tell me about The login functionality should always generate a new session id ?']
# ['Description', ' What do you know about The login functionality should always generate a new session id ?']
# ['Description', ' What can you tell me about The login functionality should always generate a new session id ?']
# ['Description', ' I want to know about XSS The login functionality should always generate a new session id']
# ['Description', ' Do you have information about The login functionality should always generate a new session id ?']
# ['Description', ' What is Does The application enforce the use of secure passwords ?']
# ['Description', ' What does Does The application enforce the use of secure passwords mean ?']
# ['Description', ' Tell me something about Does The application enforce the use of secure passwords ?']
# ['Description', ' Does The application enforce the use of secure passwords']
# ['Description', ' Explain Does The application enforce the use of secure passwords ?']
# ['Description', ' Elaborate Does The application enforce the use of secure passwords ?']
# ['Description', ' Can you tell me about Does The application enforce the use of secure passwords ?']
# ['Description', ' What do you know about Does The application enforce the use of secure passwords ?']
# ['Description', ' What can you tell me about Does The application enforce the use of secure passwords ?']
# ['Description', ' I want to know about XSS Does The application enforce the use of secure passwords']
# ['Description', ' Do you have information about Does The application enforce the use of secure passwords ?']
# ['Description', ' What is Session IDs do not timeout (idl) ?']
# ['Description', ' What does Session IDs do not timeout (idl) mean ?']
# ['Description', ' Tell me something about Session IDs do not timeout (idl) ?']
# ['Description', ' Session IDs do not timeout (idl)']
# ['Description', ' Explain Session IDs do not timeout (idl) ?']
# ['Description', ' Elaborate Session IDs do not timeout (idl) ?']
# ['Description', ' Can you tell me about Session IDs do not timeout (idl) ?']
# ['Description', ' What do you know about Session IDs do not timeout (idl) ?']
# ['Description', ' What can you tell me about Session IDs do not timeout (idl) ?']
# ['Description', ' I want to know about XSS Session IDs do not timeout (idl)']
# ['Description', ' Do you have information about Session IDs do not timeout (idl) ?']
# ['Description', ' What is Directory listing ?']
# ['Description', ' What does Directory listing mean ?']
# ['Description', ' Tell me something about Directory listing ?']
# ['Description', ' Directory listing']
# ['Description', ' Explain Directory listing ?']
# ['Description', ' Elaborate Directory listing ?']
# ['Description', ' Can you tell me about Directory listing ?']
# ['Description', ' What do you know about Directory listing ?']
# ['Description', ' What can you tell me about Directory listing ?']
# ['Description', ' I want to know about XSS Directory listing']
# ['Description', ' Do you have information about Directory listing ?']
# ['Description', ' What is Unnecessary features enabled or installed ?']
# ['Description', ' What does Unnecessary features enabled or installed mean ?']
# ['Description', ' Tell me something about Unnecessary features enabled or installed ?']
# ['Description', ' Unnecessary features enabled or installed']
# ['Description', ' Explain Unnecessary features enabled or installed ?']
# ['Description', ' Elaborate Unnecessary features enabled or installed ?']
# ['Description', ' Can you tell me about Unnecessary features enabled or installed ?']
# ['Description', ' What do you know about Unnecessary features enabled or installed ?']
# ['Description', ' What can you tell me about Unnecessary features enabled or installed ?']
# ['Description', ' I want to know about XSS Unnecessary features enabled or installed']
# ['Description', ' Do you have information about Unnecessary features enabled or installed ?']
# ['Description', ' What is Avoid the use of default and predictable acounts. ?']
# ['Description', ' What does Avoid the use of default and predictable acounts. mean ?']
# ['Description', ' Tell me something about Avoid the use of default and predictable acounts. ?']
# ['Description', ' Avoid the use of default and predictable acounts.']
# ['Description', ' Explain Avoid the use of default and predictable acounts. ?']
# ['Description', ' Elaborate Avoid the use of default and predictable acounts. ?']
# ['Description', ' Can you tell me about Avoid the use of default and predictable acounts. ?']
# ['Description', ' What do you know about Avoid the use of default and predictable acounts. ?']
# ['Description', ' What can you tell me about Avoid the use of default and predictable acounts. ?']
# ['Description', ' I want to know about XSS Avoid the use of default and predictable acounts.']
# ['Description', ' Do you have information about Avoid the use of default and predictable acounts. ?']
# ['Description', ' What is Security settings in your development frameworks ?']
# ['Description', ' What does Security settings in your development frameworks mean ?']
# ['Description', ' Tell me something about Security settings in your development frameworks ?']
# ['Description', ' Security settings in your development frameworks']
# ['Description', ' Explain Security settings in your development frameworks ?']
# ['Description', ' Elaborate Security settings in your development frameworks ?']
# ['Description', ' Can you tell me about Security settings in your development frameworks ?']
# ['Description', ' What do you know about Security settings in your development frameworks ?']
# ['Description', ' What can you tell me about Security settings in your development frameworks ?']
# ['Description', ' I want to know about XSS Security settings in your development frameworks']
# ['Description', ' Do you have information about Security settings in your development frameworks ?']
# ['Description', ' What is Insecure datastorage ?']
# ['Description', ' What does Insecure datastorage mean ?']
# ['Description', ' Tell me something about Insecure datastorage ?']
# ['Description', ' Insecure datastorage']
# ['Description', ' Explain Insecure datastorage ?']
# ['Description', ' Elaborate Insecure datastorage ?']
# ['Description', ' Can you tell me about Insecure datastorage ?']
# ['Description', ' What do you know about Insecure datastorage ?']
# ['Description', ' What can you tell me about Insecure datastorage ?']
# ['Description', ' I want to know about XSS Insecure datastorage']
# ['Description', ' Do you have information about Insecure datastorage ?']
# ['Description', ' What is Authentication based on the knowledge of a secret URL ?']
# ['Description', ' What does Authentication based on the knowledge of a secret URL mean ?']
# ['Description', ' Tell me something about Authentication based on the knowledge of a secret URL ?']
# ['Description', ' Authentication based on the knowledge of a secret URL']
# ['Description', ' Explain Authentication based on the knowledge of a secret URL ?']
# ['Description', ' Elaborate Authentication based on the knowledge of a secret URL ?']
# ['Description', ' Can you tell me about Authentication based on the knowledge of a secret URL ?']
# ['Description', ' What do you know about Authentication based on the knowledge of a secret URL ?']
# ['Description', ' What can you tell me about Authentication based on the knowledge of a secret URL ?']
# ['Description', ' I want to know about XSS Authentication based on the knowledge of a secret URL']
# ['Description', ' Do you have information about Authentication based on the knowledge of a secret URL ?']
# ['Description', ' What is Open forward and Open redirects ?']
# ['Description', ' What does Open forward and Open redirects mean ?']
# ['Description', ' Tell me something about Open forward and Open redirects ?']
# ['Description', ' Open forward and Open redirects']
# ['Description', ' Explain Open forward and Open redirects ?']
# ['Description', ' Elaborate Open forward and Open redirects ?']
# ['Description', ' Can you tell me about Open forward and Open redirects ?']
# ['Description', ' What do you know about Open forward and Open redirects ?']
# ['Description', ' What can you tell me about Open forward and Open redirects ?']
# ['Description', ' I want to know about XSS Open forward and Open redirects']
# ['Description', ' Do you have information about Open forward and Open redirects ?']
# ...
# ['Code', ' Code example of data controller display layer separation ?']
# ['Code', ' Code of data controller display layer separation']
# ['Code', ' Give me some sample code of proven authentication mechanisms']
# ['Code', ' Code example of proven authentication mechanisms ?']
# ['Code', ' Code of proven authentication mechanisms']
# ['Code', ' Give me some sample code of administrative interfaces must not be accessible to untrusted parties']
# ['Code', ' Code example of administrative interfaces must not be accessible to untrusted parties ?']
# ['Code', ' Code of administrative interfaces must not be accessible to untrusted parties']
# ['Code', ' Give me some sample code of concurrent session handling']
# ['Code', ' Code example of concurrent session handling ?']
# ['Code', ' Code of concurrent session handling']
# ['Code', ' Give me some sample code of Auto escaping technology']
# ['Code', ' Code example of Auto escaping technology ?']
# ['Code', ' Code of Auto escaping technology']
# ['Code', ' Give me some sample code of Client side storage']
# ['Code', ' Code example of Client side storage ?']
# ['Code', ' Code of Client side storage']
# ['Code', ' Give me some sample code of Log rotation and seperation']
# ['Code', ' Code example of Log rotation and seperation ?']
# ['Code', ' Code of Log rotation and seperation']
# ['Code', ' Give me some sample code of HTTP strict transport security']
# ['Code', ' Code example of HTTP strict transport security ?']
# ['Code', ' Code of HTTP strict transport security']
# ['Code', ' Give me some sample code of API resonses security headers']
# ['Code', ' Code example of API resonses security headers ?']
# ['Code', ' Code of API resonses security headers']
# ['Code', ' Give me some sample code of Do not support untrusted client side technologies']
# ['Code', ' Code example of Do not support untrusted client side technologies ?']
# ['Code', ' Code of Do not support untrusted client side technologies']
# ['Code', ' Give me some sample code of Signed message payloads']
# ['Code', ' Code example of Signed message payloads ?']
# ['Code', ' Code of Signed message payloads']
# ['Code', ' Give me some sample code of Hardware key vault']
# ['Code', ' Code example of Hardware key vault ?']
# ['Code', ' Code of Hardware key vault']
# ['Code', ' Give me some sample code of SOAP basic profile']
# ['Code', ' Code example of SOAP basic profile ?']
# ['Code', ' Code of SOAP basic profile']
# ['Code', ' Give me some sample code of Strong CRYPTO through CA hierachy']
# ['Code', ' Code example of Strong CRYPTO through CA hierachy ?']
# ['Code', ' Code of Strong CRYPTO through CA hierachy']
# ['Code', ' Give me some sample code of Build and deploy in a secure fashion']
# ['Code', ' Code example of Build and deploy in a secure fashion ?']
# ['Code', ' Code of Build and deploy in a secure fashion']
# ['Code', ' Give me some sample code of Signed application components']
# ['Code', ' Code example of Signed application components ?']
# ['Code', ' Code of Signed application components']
# ['Code', ' Give me some sample code of Build proccess security hardening']
# ['Code', ' Code example of Build proccess security hardening ?']
# ['Code', ' Code of Build proccess security hardening']
# ['Code', ' Give me some sample code of Sanitize unstructured data']
# ['Code', ' Code example of Sanitize unstructured data ?']
# ['Code', ' Code of Sanitize unstructured data']
# ['Code', ' Give me some sample code of Zero keys and secrets before destroying them']
# ['Code', ' Code example of Zero keys and secrets before destroying them ?']
# ['Code', ' Code of Zero keys and secrets before destroying them']
# ['Code', ' Give me some sample code of Keys and passwords should be replaceable']
# ['Code', ' Code example of Keys and passwords should be replaceable ?']
# ['Code', ' Code of Keys and passwords should be replaceable']
# ['Code', ' Give me some sample code of Enforce random numbers are created with proper entropy at runtime']
# ['Code', ' Code example of Enforce random numbers are created with proper entropy at runtime ?']
# ['Code', ' Code of Enforce random numbers are created with proper entropy at runtime']
# ['Code', ' Give me some sample code of Segregated components']
# ['Code', ' Code example of Segregated components ?']
# ['Code', ' Code of Segregated components']
# ['Code', ' Give me some sample code of PII protection']
# ['Code', ' Code example of PII protection ?']
# ['Code', ' Code of PII protection']
# ['Code', ' Give me some sample code of Verify application is not vulnerable for known security issues']
# ['Code', ' Code example of Verify application is not vulnerable for known security issues ?']
# ['Code', ' Code of Verify application is not vulnerable for known security issues']
# ['Code', ' Give me some sample code of Disable autocomplete for all the input fields in forms']
# ['Code', ' Code example of Disable autocomplete for all the input fields in forms ?']
# ['Code', ' Code of Disable autocomplete for all the input fields in forms']
# ['Code', ' Give me some sample code of All time sources should be synchronized']
# ['Code', ' Code example of All time sources should be synchronized ?']
# ['Code', ' Code of All time sources should be synchronized']
# ['Code', ' Give me some sample code of Generate strong crypto tokens with at least 120 bit of effective entropy']
# ['Code', ' Code example of Generate strong crypto tokens with at least 120 bit of effective entropy ?']
# ['Code', ' Code of Generate strong crypto tokens with at least 120 bit of effective entropy']
# ['Code', ' Give me some sample code of Enforce sensitive information to be stored encrypted on device']
# ['Code', ' Code example of Enforce sensitive information to be stored encrypted on device ?']
# ['Code', ' Code of Enforce sensitive information to be stored encrypted on device']
# ['Code', ' Give me some sample code of Encrypt sensitive information different depending on context']
# ['Code', ' Code example of Encrypt sensitive information different depending on context ?']
# ['Code', ' Code of Encrypt sensitive information different depending on context']
# ['Code', ' Give me some sample code of Secrets should be secure random generated']
# ['Code', ' Code example of Secrets should be secure random generated ?']
# ['Code', ' Code of Secrets should be secure random generated']
# ['Code', ' Give me some sample code of Protection against different exfiltration techniques']
# ['Code', ' Code example of Protection against different exfiltration techniques ?']
# ['Code', ' Code of Protection against different exfiltration techniques']
# ['Code', ' Give me some sample code of Principle of least privilege']
# ['Code', ' Code example of Principle of least privilege ?']
# ['Code', ' Code of Principle of least privilege']
# ['Code', ' Give me some sample code of Protecting device memory']
# ['Code', ' Code example of Protecting device memory ?']
# ['Code', ' Code of Protecting device memory']
# ['Code', ' Give me some sample code of Enforce anti']
# ['Code', ' Code example of Enforce anti ?']
# ['Code', ' Code of Enforce anti']
# ['Code', ' Give me some sample code of Protect sensitive activities intents or content providers']
# ['Code', ' Code example of Protect sensitive activities intents or content providers ?']
# ['Code', ' Code of Protect sensitive activities intents or content providers']
# ['Code', ' Give me some sample code of Mitigate memory dumping attacks']
# ['Code', ' Code example of Mitigate memory dumping attacks ?']
# ['Code', ' Code of Mitigate memory dumping attacks']
# ['Code', ' Give me some sample code of Protect agains exported activities or content providers']
# ['Code', ' Code example of Protect agains exported activities or content providers ?']
# ['Code', ' Code of Protect agains exported activities or content providers']
# ['Code', ' Give me some sample code of Block common password and weak passphrases']
# ['Code', ' Code example of Block common password and weak passphrases ?']
# ['Code', ' Code of Block common password and weak passphrases']
# ['Code', ' Give me some sample code of Application assets hosted on secure location']
# ['Code', ' Code example of Application assets hosted on secure location ?']
# ['Code', ' Code of Application assets hosted on secure location']
# ['Code', ' Give me some sample code of CSRF on REST']
# ['Code', ' Code example of CSRF on REST ?']
# ['Code', ' Code of CSRF on REST']
# ['Code', ' Give me some sample code of File']
# ['Code', ' Code example of File ?']
# ['Code', ' Code of File']
# ['Code', ' Give me some sample code of File upload anti virus check']
# ['Code', ' Code example of File upload anti virus check ?']
# ['Code', ' Code of File upload anti virus check']
# ['Code', ' Give me some sample code of File upload outside document root']
# ['Code', ' Code example of File upload outside document root ?']
# ['Code', ' Code of File upload outside document root']
# ['Code', ' Give me some sample code of Unauthorized and unauthenticated access security logs']
# ['Code', ' Code example of Unauthorized and unauthenticated access security logs ?']
# ['Code', ' Code of Unauthorized and unauthenticated access security logs']
# ['Code', ' Give me some sample code of Commonly chosen weak passwords and passphrases']
# ['Code', ' Code example of Commonly chosen weak passwords and passphrases ?']
# ['Code', ' Code of Commonly chosen weak passwords and passphrases']
# ['Code', ' Give me some sample code of two factor authentication against username password disclosure']
# ['Code', ' Code example of two factor authentication against username password disclosure ?']
# ['Code', ' Code of two factor authentication against username password disclosure']
# ['Code', ' Give me some sample code of Logging access control decisions']
# ['Code', ' Code example of Logging access control decisions ?']
# ['Code', ' Code of Logging access control decisions']
# ['Code', ' Give me some sample code of High value transactions']
# ['Code', ' Code example of High value transactions ?']
# ['Code', ' Code of High value transactions']
# ['Code', ' Give me some sample code of Verify that structured data is strongly typed and validated']
# ['Code', ' Code example of Verify that structured data is strongly typed and validated ?']
# ['Code', ' Code of Verify that structured data is strongly typed and validated']
# ['Code', ' Give me some sample code of Logging guidelines to access sensitive information']
# ['Code', ' Code example of Logging guidelines to access sensitive information ?']
# ['Code', ' Code of Logging guidelines to access sensitive information']
# ['Code', ' Give me some sample code of Log injection']
# ['Code', ' Code example of Log injection ?']
# ['Code', ' Code of Log injection']
# ['Code', ' Give me some sample code of Validate the integrity of all security relevant configurations']
# ['Code', ' Code example of Validate the integrity of all security relevant configurations ?']
# ['Code', ' Code of Validate the integrity of all security relevant configurations']
# ['Code', ' Give me some sample code of Trusted repositories']
# ['Code', ' Code example of Trusted repositories ?']
# ['Code', ' Code of Trusted repositories']
# ['Code', ' Give me some sample code of Sandboxing malicious code']
# ['Code', ' Code example of Sandboxing malicious code ?']
# ['Code', ' Code of Sandboxing malicious code']
# ['Code', ' Give me some sample code of Client side constraints']
# ['Code', ' Code example of Client side constraints ?']
# ['Code', ' Code of Client side constraints']
# ['Code', ' Give me some sample code of Context sensitive authorization']
# ['Code', ' Code example of Context sensitive authorization ?']
# ['Code', ' Code of Context sensitive authorization']
# ['Code', ' Give me some sample code of All access controls must fail securely']
# ['Code', ' Code example of All access controls must fail securely ?']
# ['Code', ' Code of All access controls must fail securely']
# ['Code', ' Give me some sample code of Password leakage']
# ['Code', ' Code example of Password leakage ?']
# ['Code', ' Code of Password leakage']
# ['Code', ' Give me some sample code of TLS implementation']
# ['Code', ' Code example of TLS implementation ?']
# ['Code', ' Code of TLS implementation']
# ['Code', ' Give me some sample code of Screen scraping data harvest']
# ['Code', ' Code example of Screen scraping data harvest ?']
# ['Code', ' Code of Screen scraping data harvest']
# ['Code', ' Give me some sample code of Communication between components (low privileges)']
# ['Code', ' Code example of Communication between components (low privileges) ?']
# ['Code', ' Code of Communication between components (low privileges)']
# ['Code', ' Give me some sample code of TLS settings are in line with current leading practice']
# ['Code', ' Code example of TLS settings are in line with current leading practice ?']
# ['Code', ' Code of TLS settings are in line with current leading practice']
# ['Code', ' Give me some sample code of Data retention policy']
# ['Code', ' Code example of Data retention policy ?']
# ['Code', ' Code of Data retention policy']
# ['Code', ' Give me some sample code of authenticated data cleared from client storage']
# ['Code', ' Code example of authenticated data cleared from client storage ?']
# ['Code', ' Code of authenticated data cleared from client storage']
# ['Code', ' Give me some sample code of File inclusion attack II']
# ['Code', ' Code example of File inclusion attack II ?']
# ['Code', ' Code of File inclusion attack II']
# ['Code', ' Give me some sample code of Sensitive information in code or online repositories']
# ['Code', ' Code example of Sensitive information in code or online repositories ?']
# ['Code', ' Code of Sensitive information in code or online repositories']
# ['Code', ' Give me some sample code of Identify all components']
# ['Code', ' Code example of Identify all components ?']
# ['Code', ' Code of Identify all components']
# ['Code', ' Give me some sample code of Display concurrent and active sessions']
# ['Code', ' Code example of Display concurrent and active sessions ?']
# ['Code', ' Code of Display concurrent and active sessions']
# ['Code', ' Give me some sample code of Password change leads to destroying concurrent sessions']
# ['Code', ' Code example of Password change leads to destroying concurrent sessions ?']
# ['Code', ' Code of Password change leads to destroying concurrent sessions']
# ['Code', ' Give me some sample code of HSTS preload']
# ['Code', ' Code example of HSTS preload ?']
# ['Code', ' Code of HSTS preload']
# ['Code', ' Give me some sample code of Integrity check and authorised modification']
# ['Code', ' Code example of Integrity check and authorised modification ?']
# ['Code', ' Code of Integrity check and authorised modification']
# ['Code', ' Give me some sample code of Unauthorised access and modification']
# ['Code', ' Code example of Unauthorised access and modification ?']
# ['Code', ' Code of Unauthorised access and modification']
# ['Code', ' Give me some sample code of Identify and use only require functions if using components']
# ['Code', ' Code example of Identify and use only require functions if using components ?']
# ['Code', ' Code of Identify and use only require functions if using components']
# ['Code', ' Give me some sample code of Centralized the mechanisms for protecting resources and the access']
# ['Code', ' Code example of Centralized the mechanisms for protecting resources and the access ?']
# ['Code', ' Code of Centralized the mechanisms for protecting resources and the access']
# ['Code', ' Give me some sample code of Third party components']
# ['Code', ' Code example of Third party components ?']
# ['Code', ' Code of Third party components']
# ['Code', ' Give me some sample code of Policy for processing sensitive data']
# ['Code', ' Code example of Policy for processing sensitive data ?']
# ['Code', ' Code of Policy for processing sensitive data']
# ['Code', ' Give me some sample code of Server side request forgery']
# ['Code', ' Code example of Server side request forgery ?']
# ['Code', ' Code of Server side request forgery']
# ['Code', ' Give me some sample code of not available item']
# ['Code', ' Code example of not available item ?']
# ['Code', ' Code of not available item']
